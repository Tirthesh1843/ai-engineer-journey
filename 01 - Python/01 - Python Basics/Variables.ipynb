# %% [markdown]
# # Variables

# %% [markdown]
# ## Variables are the aliments in python that can be used for storing data into it or values into it or they can be referred as container as well.
# ## Variables as per name its name, data can vary that we are going to store into it and once we have declared a variable we can vary the value stored into it.

# %%
age = 23
Name = 'Tirthesh'
Height = 5.9
Is_True = True

# %%
age
# Out:
# 23

# %%
Height
# Out:
# 5.9

# %%
Name
# Out:
# 'Tirthesh'

# %% [markdown]
# ## Print()

# %% [markdown]
# ### Print() --> Print function is used to represent the value that that we are going to pass inside it.

# %%
print(age)
# Out:
# 23

# %%
print(Name)
# Out:
# Tirthesh

# %%
print ("My name is", Name)
# Out:
# My name is Tirthesh

# %%
print("My age is", age)
# Out:
# My age is 23

# %% [markdown]
# ## Comment

# %% [markdown]
# ### Comment is a statement in a program that we do not want the interpreter to execute.
# ### Interpreter --> executes the code line by line in Python language.
# ### Compiler --> executes the code completely.

# %%
# hello This is a comment.

# %%
'''hello
this is a multiuple line
comment.'''
# Out:
# 'hello\nthis is a multiuple line'

# %% [markdown]
# ## Variable naming Convention

# %%
'''Variable name must be Descriptive
name = 'Tirthesh'
age = 23'''
# Out:
# "Variable name must be Descriptive\nname = 'Tirthesh'\nage = 23"

# %%
'''They must start wit letter or _
1name = 'Tirthesh'
_age = 23   '''
# Out:
# "They must start wit letter or _\n1name = 'Tirthesh'\n_age = 23   "

# %%
'''Variables are case sensitive
Name = 'Tirthesh'
name = 'Tirthesh' '''

# %%
Name = 'Tirthesh'
name = 'Tirthesh'
Name == name
# Out:
# True

# %%
age = 23
Name = "Tirthesh"
Height = 5.11
is_true = True

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(age)
# Out:
# 23

# %%
age = 55
print(age)
# Out:
# 55

# %%
age = str(age)

# %%
type(age)
# Out:
# str

# %%
'''
Every typecasting is not possible.
int --> str
str xx--> str
'''
# Out:
# '\nEvery typecasting is not possible.\nint --> str\nstr xx--> str\n'

# %% [markdown]
# # input()
# ## input() can take the input from the user sidew and then can store that input into a variable.

# %%
Name=input("Enter your name")

# %%
print(Name)
# Out:
# Tirthesh

# %% [markdown]
# ### input function only takes the input in strin format until and unless we are not going to take explicitly take the input in int or other format.

# %%
age=input("Enter your age: ")

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age = int(input("Enter your age: "))

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
## building a simple calculator:
value1 = int(input("Enter the first value: "))
value2 = int(input("Enter the second value: "))
print("Addition: ", value1 + value2)
print("Subtraction: ", value1 - value2)
print("Multiplication: ", value1 * value2)
print("Division: ", value1 / value2)
# Out:
# Addition:  5
# Subtraction:  -1
# Multiplication:  6
# Division:  0.6666666666666666
