# %% [markdown]
# # What is Python Language?

# %% [markdown]
# ## Python is a type of programming language which we can use for communicating with commputers or technologies.

# %% [markdown]
# # Syntax for python Language

# %% [markdown]
# syntax refersa to the set of rules that defines the combination of symbols that are considered to be correctly structured programs in a language.

# %% [markdown]
# # Symentics of Python Language

# %% [markdown]
# ## Symentics of python language refers to the meaning or interpretation of Symbols, Characters and Commands in a language.It is about what the code is supposed to do when it runs.

# %% [markdown]
# # Python Syntax Rules

# %% [markdown]
# ## 1. Python is case sensitive

# %%
name = "Amit"
Name = "Amit"
name == Name
# Out:
# True

# %%
name = "Amit"
Name = "amit"
name == Name
# Out:
# False

# %% [markdown]
# ## Indentation in Python

# %% [markdown]
# ### In other programming language, we use {} for grouping of statements
# ### In python, we use indentation for proper grouping of statements as the proper arragement of statements with proper spacing in the statements within a block.

# %%
age = int(input("Enter your age: "))
if age > 18:
    print("You can drive")
else:   
    print("You can't drive")
# Out:
# You can drive

# %%
1+2+3+4+5+6
# Out:
# 21

# %%
1+2+3+4+5+\
    6+7
# Out:
# 28

# %% [markdown]
# ## Line Continuation --> we can use Backslash for continuingstatement on the next line

# %% [markdown]
# ## Multiple Statements In a single line in Python

# %%
a=5 b=7
# Out:
#   Cell In[6], line 1
#     a=5 b=7
#         ^
# SyntaxError: invalid syntax

# %%
a=1;b = 6; c = 8
