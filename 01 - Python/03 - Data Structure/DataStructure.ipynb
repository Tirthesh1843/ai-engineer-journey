# %% [markdown]
# # Data Structure in Python

# %% [markdown]
# #### Data Structures in Python are being used for storing the data in structured format so that we can access the data and along with that we can perform all of the operaqtions with these data structures that we can perform in the case of data bases as well like crud (Create, Read, Update, Delete) operations.

# %% [markdown]
# ## Types of Data Structure in Python aRE:
# 1. List
# 2. Tuple
# 3. Set
# 4. Dictionary

# %% [markdown]
# ### the different types of data structure differs on this basis that in which specific format we want to store our data.
