# %% [markdown]
# # Modules and Packages

# %%
def addition (num1,num2):
    return num1+num2

# %%
addition(1,2)
# Out:
# 3

# %% [markdown]
# ### I want to use this function into some another file.

# %%
import math
math.sqrt(4)
# Out:
# 2.0

# %%
### How complex the logic of a square root function is going to be?

# %% [markdown]
# ## Module
#
# #### A module in python is simply a file containing python code (functions, Classes or Variables) that can be imported and used in other programs.

# %% [markdown]
# ### Numpy:
# #### Numpy module is going to help us out with applying scientific calculations on the array and we can store our data by consuming less space and we can apply the operations with our array a bit more faster compare to those of the list.
#
# #### We can do it in Numpy just because numpy is having the collections of functions and attributes which can help us to work efficiently with the array.

# %% [markdown]
# ### Pandas:
#
# #### Pandas we can use when we are going to work with a dataset for cleaning, Pre Processing, EDA, analysis with plotting as well.

# %%
import math
math.sqrt(81)
# Out:
# 9.0

# %%
from math import sqrt
sqrt(121)
# Out:
# 11.0

# %%
from math import *
print(pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ### A Module:
#
# 1. A module helps in code organization.
# 2. It promotes reusability.
# 3. It keeps the code clean and manageable as well.

# %%
print(cos(90))
# Out:
# -0.4480736161291701

# %%
print(factorial(5))
# Out:
# 120

# %%
import numpy # We have to install numpy first with pip install numpy

# %%
list_items = [1,2,3,4,5]
numpy_array= numpy.array(list_items)
type(numpy_array)
print(numpy_array)
# Out:
# [1 2 3 4 5]

# %%
print(type(numpy_array))
# Out:
# <class 'numpy.ndarray'>

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached pandas-3.0.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.3 MB 5.0 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.3 MB 3.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.6/9.3 MB 4.1 MB/s eta 0:00:02
#    -------------- ------------------------- 3.4/9.3 MB 4.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.3 MB 4.1 MB/s eta 0:00:02
#    --------------------- ------------------ 5.0/9.3 MB 4.0 MB/s eta 0:00:02
#    ------------------------- -------------- 6.0/9.3 MB 4.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.8/9.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.3 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 4.3 MB/s  0:00:02
# ...

# %% [markdown]
# ### I am trying to create my own library or Module and in this library i want the functions and the attributes to be created of my own.

# %%
## __init__.py is a file that has to be there inside the package folder and this __init__,py file helps us out in defining packages and initializing their namespaces.

# %%
## __init__.py this file can remain empty and it's completely fine but this file has to be there when we will be creating our new packages into the package folder.

# %%
from package_folder.mathematics import addition

# %%
addition(4,9)
# Out:
# 13

# %%
from package_folder.mathematics import *
division(4,0)
# Out:
# 'Enter the valid value.'

# %%
division(4,2)
# Out:
# 2.0

# %%
# in .py file
# cd python file_name.py

# %%
from package_folder.supackage.sum import *
addition(5,2,6)
# Out:
# 13
