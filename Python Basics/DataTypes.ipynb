# %% [markdown]
# # Data Types

# %% [markdown]
# ## Data types are classification of data that tells the compiler or the interpreter that what type of value we can store in variable and how much amount of memory will be consume to store data and the operation it can perform.

# %%
age = int(input("Please enter your age: "))
