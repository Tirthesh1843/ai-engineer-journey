# %% [markdown]
# # List

# %% [markdown]
# ## List are one of the type of Data Structures which are used to storing the data in structured format where you can store data of any data type and that is oone of the data structure so we can have access to the data as well that we are going to store into the list and we can apply CRUD Operation as well i.e Create, Update, Delete, Read Operation as well.

# %%
a = list()
type(a)
# Out:
# list
