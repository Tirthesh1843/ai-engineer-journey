# %% [markdown]
# # Streamlit

# %% [markdown]
# ## Stremlit is an opensource python library used to build beautiful, Interactive, Web applications for Data Science and Machine learning with menimum effort.

# %% [markdown]
# ## Why to use streamlit.
#
# #### Stremlit is easy tom use.
# #### Fast Developments.
# #### Interactive UI Elements ---> Buttons, Text Inputs, Charts etc.
# #### Great for data Science ---> It supports Pandas, Matplotlib, Plotly and Other Libraries
# #### Deployment is easy
