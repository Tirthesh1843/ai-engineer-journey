# %% [markdown]
# # Pandas Fundamentals

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Pandas is Powerful library that is used for Data Analysis and Data Manipulation. It helps us to work with data in tabular format, Just like how we deal with data and spreadsheets in Excel or Database.

# %% [markdown]
# ## Pandas provides functionalities and attributes to clean, organize and analyze large amounts of data.

# %% [markdown]
# #### 1. pandas is easy to use. ---> Works like excel in python.
# #### 2. Fast ---> Handles large data sets easily.
# #### 3. Cleaning data is easy ---> Missing values, duplicates,messy data etc.
# #### 4. Integrates well with other libraries like numpy, matplotlib, seaborn etc.
# #### 5. Ideal for ML and AI ---> It is ideal for Data science field.
