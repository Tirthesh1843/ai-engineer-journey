# %% [markdown]
# # Real World Dataset

# %%
## read_csv() ---> this function reads the content from csv file in Pandas so that we can perform operations on the data or we can perform effective analysis.

# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("C:/Users/TIRTHESH/Downloads/archive/youtube_2025_dataset_202504061614.csv")
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
df=pd.read_csv('youtube_2025_dataset.csv')

# %%
df
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
# Dataframe ---> Combination of Multiple Series (Column).

# %%
## squeeze() ---> Squeeze parameter make sure that the data is in series format.

# %%
type(pd.read_csv("youtube_one.csv"))
# Out:
# pandas.DataFrame

# %%
df = pd.read_csv("youtube_one.csv").squeeze("columns")

# %%
type(df)
# Out:
# pandas.Series

# %%
dataframe = pd.read_csv("youtube_two.csv",index_col="Channel Name").squeeze("columns")

# %%
dataframe
# Out:
# Channel Name
# Smith-Ross Labs                 68
# Sandoval PLC Hub               128
# Jones, Moore and Ho Network    282
# Mitchell-Hooper Labs           302
# Wilson LLC Studios             129
#                               ...
# Flores-Daniel Studios          106
# Spencer and Sons Studios       130
# Obrien-Roberts Studios         179
# King Ltd Hub                   182
# Henry Ltd Studios               92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
# attributes of series
## 1. values ---> representing onlly the values of the given series.
## 2. index ---> representing the index of the series
## 3. dtype ---> representing the data type of the series
## 4. name ---> representing the name of the series
## 5. size ---> Provides the idea about the total no. of rows in the series.
## 6. shape ---> Idea about rows and columns.
## 7. ndim ---> Idea about the dimension of the series.
## 8. is_unique ---> True if the index is unique else False

# %%
dataframe.values
# Out:
# array([ 68, 128, 282, ..., 179, 182,  92], shape=(5000,))

# %%
dataframe.index
# Out:
# Index(['Smith-Ross Labs', 'Sandoval PLC Hub', 'Jones, Moore and Ho Network',
#        'Mitchell-Hooper Labs', 'Wilson LLC Studios', 'Myers Ltd Network',
#        'Huber Inc Network', 'Baxter-Collins Studios', 'Morrow-Abbott Hub',
#        'Jackson Group Network',
#        ...
#        'Cole-Sharp Labs', 'Sherman, Mcgee and Phillips Studios',
#        'Baker-Hill Hub', 'Francis, Davis and Jones Network',
#        'Whitaker, Horn and Escobar Labs', 'Flores-Daniel Studios',
#        'Spencer and Sons Studios', 'Obrien-Roberts Studios', 'King Ltd Hub',
#        'Henry Ltd Studios'],
#       dtype='str', name='Channel Name', length=5000)

# %%
dataframe.dtype
# Out:
# dtype('int64')

# %%
dataframe.name
# Out:
# 'Total Videos'

# %%
dataframe = dataframe.astype('int32')

# %%
dataframe.dtype
# Out:
# dtype('int32')

# %%
dataframe.size
# Out:
# 5000

# %%
dataframe.shape
# Out:
# (5000,)

# %%
dataframe.ndim
# Out:
# 1

# %%
dataframe.is_unique
# Out:
# False

# %%
## Series Method

## 1. head() ---> Provides top preview of data as the top 5 rows of the dataframe or series.
## 2. tail() ---> Provides bottom preview of data as the bottom 5 rows of the dataframe or series.

# %%
dataframe.head(10)
# Out:
# Channel Name
# Smith-Ross Labs                 68
# Sandoval PLC Hub               128
# Jones, Moore and Ho Network    282
# Mitchell-Hooper Labs           302
# Wilson LLC Studios             129
# Myers Ltd Network               98
# Huber Inc Network              494
# Baxter-Collins Studios         133
# Morrow-Abbott Hub              316
# Jackson Group Network          140
# Name: Total Videos, dtype: int32

# %%
dataframe.tail(8)
# Out:
# Channel Name
# Baker-Hill Hub                      261
# Francis, Davis and Jones Network    126
# Whitaker, Horn and Escobar Labs     231
# Flores-Daniel Studios               106
# Spencer and Sons Studios            130
# Obrien-Roberts Studios              179
# King Ltd Hub                        182
# Henry Ltd Studios                    92
# Name: Total Videos, dtype: int32
